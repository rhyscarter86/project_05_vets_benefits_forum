# %% [markdown]
# # Data Gathering

# %% [markdown]
# This workbook describes data collection from the Vetsbenefits.net web forum. This web forum consists of two major areas of interest:
#
# * **A top level discussion board**, made up of the 500 most recently active threads (active meaning there has been a post made to the thread); and,
# * **The threads themselves**, comprising of an original post, plus one or more replies
#
# Beautiful soup was the primary means for performing this data collection. A separate workbook catalogs a similar effort capture data not in a tabular form, but in a more flexible data dictionary format for future use.

# %% [markdown]
# ### Standard Packages

# %%
import pickle

# %%
from bs4 import BeautifulSoup
import requests

# %%
from IPython.core.display import display, HTML

# %%
import time, os

# %%
import pandas as pd

# %%
import numpy as np

# %%
import regex as re

# %%
from time import sleep
from random import randint

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import datetime
import seaborn as sns

# %%
from datetime import datetime as dt

# %%
# Make better use of Jupyter Notebook cell width
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))

pd.set_option('display.max_rows', 660)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 400)
pd.options.display.float_format = '{:,.10f}'.format
# Out:
# <style>.container { width:95% !important; }</style>

# %%
#pickle.dump(df_discussion_links, open("df_discussion_links_2020-03-09_12PM.p", "wb"))

df_discussion_links_pickle = pickle.load(open("df_discussion_links_2020-03-09_12PM.p", "rb"))

# %%
#pickle.dump(df_zipped_post2, open("df_zipped_post2_2020-03-09_01AM.p", "wb"))

df_zipped_post2_pickle = pickle.load(open("df_zipped_post2_2020-03-09_01AM.p", "rb"))

# %%
df_zipped_post2_pickle.shape
# Out:
# (13955, 5)

# %% [markdown]
# ### Capture Data from Top Level Discussion Board
# ...using Beautiful Soup to move through pagination

# %%
def get_links(base_url,end):
    
    #Get base source data
    source_code = requests.get(base_url)   
    soup = BeautifulSoup(source_code.text, 'html5lib')
    
    #Get topic titles
    topic_titles=[]
    for element in soup.find_all("a", class_="topictitle shRt_t"):
        topic_titles.append(element.text)
        
    #Get last post time
    last_post_time=[]
    for index, element in enumerate(soup.find_all('span',class_="timespan")):
        if index % 2 == 0:
#    for element in soup.find_all('span',class_="timespan"):
            last_post_time.append(element['title'])   
    
#     if last_post_time[24] > recent_post_time[0]:
#         last_post_time_copy = last_post_time.copy()
#         recent_post_time.insert(0,last_post_time_copy[0])
#         ret
    
    
    
    #Get links for topics
    links_with_text = []
    for a in soup.find_all('a', class_="topictitle shRt_t", href=True): 
        if a.text: 
            links_with_text.append(a['href'])
   
    print('done page 1')
    
    #Loop through subsequent pages
    for i in list(range(25,end,25)):
        
        #Get source code
        source_code = requests.get(base_url + '&start={}'.format(i))
        soup = BeautifulSoup(source_code.text, 'html5lib')
    
        #Get topic titles
        for element in soup.find_all("a", class_="topictitle shRt_t"):
            topic_titles.append(element.text)

        #Get last post time
        for index, element in enumerate(soup.find_all('span',class_="timespan")):
            if index % 2 == 0:
        #    for element in soup.find_all('span',class_="timespan"):
                last_post_time.append(element['title'])    
        
        #Get links for topics
        for a in soup.find_all('a', class_="topictitle shRt_t", href=True): 
            if a.text: 
                links_with_text.append(a['href'])
                
        #Pause
        print('done page {}'.format(i))
        sleep(randint(5,10))
   
    #Zip cols and create DF        
    post_zip = zip(topic_titles, links_with_text, last_post_time) 
    zipped_list = list(post_zip) #Convert zip to list.
    df_zipped_links = pd.DataFrame(zipped_list, columns=['post','url','last_post_time'])
    
    df_zipped_links['url'] = [x[:-42] for x in df_zipped_links['url']]
    
    df_zipped_links[['last_post_hour','last_post_date']] = df_zipped_links.last_post_time.str.split("-",expand=True) 
    df_zipped_links['last_post_date'] = pd.to_datetime(df_zipped_links['last_post_date'])
    df_zipped_links['last_post_hour'] = pd.to_datetime(df_zipped_links['last_post_hour']).dt.time
    df_zipped_links['combined_time'] = df_zipped_links.apply(lambda r : pd.datetime.combine(r['last_post_date'],r['last_post_hour']),1)
    
    # Filter out anything that isn't newer than most recent time saved
    #df_zipped_links = df_zipped_links[df_zipped_links['combined_time'] >= recent_post_time[0]]
    #recent_post_time.insert(0,df_zipped_links.combined_time[0])
    
    return df_zipped_links

# %%
df_discussion_links_no_dict_2 = get_links('https://vetsbenefits.net/discussion/all?sr=topics&search_id=newposts&discussions=1&unlimit=1',501)
# Out:
# done page 1
# done page 25
# done page 50
# done page 75
# done page 100
# done page 125
# done page 150
# done page 175
# done page 200
# done page 225
# done page 250
# done page 275
# done page 300
# done page 325
# done page 350
# done page 375
# done page 400
# done page 425
# done page 450
# done page 475
# done page 500
# <ipython-input-16-628be1a31c1a>:70: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   df_zipped_links['combined_time'] = df_zipped_links.apply(lambda r : pd.datetime.combine(r['last_post_date'],r['last_post_hour']),1)

# %%
df_discussion_links_no_dict['url'] = [x[:-42] for x in df_discussion_links_no_dict['url']]

# %%
df_discussion_links_no_dict_2.head()
# Out:
#                       post  \
# 0          ChampVA  Claims
# 1  Monday Moring Roll Call
# 2            PTSD Increase
# 3       Old or new rating?
# 4                VA Travel
#
#                                                         url  \
# 0           https://vetsbenefits.net/champva-claims-t193856
# 1  https://vetsbenefits.net/monday-moring-roll-call-t193855
# 2            https://vetsbenefits.net/ptsd-increase-t192490
# 3        https://vetsbenefits.net/old-or-new-rating-t193810
# 4                https://vetsbenefits.net/va-travel-t193742
#
#             last_post_time last_post_hour last_post_date       combined_time
# 0  10:05 AM - Mar 22, 2021       10:05:00     2021-03-22 2021-03-22 10:05:00
# 1  10:01 AM - Mar 22, 2021       10:01:00     2021-03-22 2021-03-22 10:01:00
# 2   9:41 AM - Mar 22, 2021       09:41:00     2021-03-22 2021-03-22 09:41:00
# 3   9:12 AM - Mar 22, 2021       09:12:00     2021-03-22 2021-03-22 09:12:00
# 4   9:10 AM - Mar 22, 2021       09:10:00     2021-03-22 2021-03-22 09:10:00

# %% [markdown]
# ### Capture Data from Individual Threads
# ...including moving through pagination on specific threads as needed

# %%
# Global data containers
post_id_container = []
original_post_id_container = []
topic_titles_posts = []
post_text=[]
post_time = []
post_author=[]

# %%
def capture_post(url):    
    ############
    # New Post #
    ############    

    #Get soup info
    source_code = requests.get(url+'.html')
    soup = BeautifulSoup(source_code.text, 'html5lib')
    
    #Get topic title for page 1
    topic_title = soup.find('h2', class_ = "topic-title").text
    
    #Get post IDs
    original_post = soup.find('div', class_=["normal-bubble post_content post-bubble-outter-padding bg1",
                                      "normal-bubble post_content post-bubble-outter-padding bg2"], id=True)

    for a in soup.find_all('div', class_=["normal-bubble post_content post-bubble-outter-padding bg1",
                                      "normal-bubble post_content post-bubble-outter-padding bg2"], id=True): 
        post_id_container.append(a['id'])
        original_post_id_container.append(original_post['id'])
        topic_titles_posts.append(topic_title)
    
    #Get post text
    for element in soup.find_all("div", class_="content noskim"):
        post_text.append(element.text)
    
    #Get Post Time
    for a in soup.find_all('span', class_="timespan", title=True): 
        if a.text: 
            post_time.append(a['title'])
    
    #Get poster name
    for element in soup.find_all('script', text = re.compile("POST_AUTHOR")):

        J = str(element)
        J1 = J.split('{')
        J2 = J1[1].split(',')
        post_author.append(J2[0].split(':'))

    print('finished page {}'.format(topic_title))
    
#     # Check if next button is present
    next_button = soup.find('i', class_="icon fa-chevron-right fa-fw")

#     if next_button:
#         print("next url is " + url + '-s{}.html'.format(40))
#         continue 
#     else:
#         print('no more pages')
#         return None
    
    ###################
    # Loop Thru Pages #
    ###################    

    if next_button:
        s = 40
        counter = 2

        while True:

            source_code = requests.get(url + '-s{}.html'.format(s))
            soup = BeautifulSoup(source_code.text, 'html5lib')

            #Get topic title for page 1
            topic_title = soup.find('h2', class_ = "topic-title").text
    
            #Get post IDs
            for a in soup.find_all('div', class_=["normal-bubble post_content post-bubble-outter-padding bg1",
                                              "normal-bubble post_content post-bubble-outter-padding bg2"], id=True): 
                post_id_container.append(a['id'])
                original_post_id_container.append(post_id_container[0])
                topic_titles_posts.append(topic_title)

            #Get post text
            for element in soup.find_all("div", class_="content noskim"):
                post_text.append(element.text)

            #Get Post Time
            for a in soup.find_all('span', class_="timespan", title=True): 
                if a.text: 
                    post_time.append(a['title'])

            #Get poster name
            for element in soup.find_all('script', text = re.compile("POST_AUTHOR")):

                J = str(element)
                J1 = J.split('{')
                J2 = J1[1].split(',')
                post_author.append(J2[0].split(':'))

            next_button = soup.find('i', class_="icon fa-chevron-right fa-fw")

            if next_button:
                s += 40
                print("done page {}".format(counter))
                print("next url is " + url + '-s{}.html'.format(s))
                counter += 1
            else:
                break 

            sleep(randint(5,10))
    else:
        return None

# %%
for i in df_discussion_links_no_dict_2.url:
    if i == 'https://vetsbenefits.net/supper-t180378':
        pass
    else:
        capture_post(i)
# Out:
# finished page ChampVA  Claims
# finished page Monday Moring Roll Call
# finished page PTSD Increase
# finished page Old or new rating?
# finished page VA Travel
# finished page Received First Moderna Vaccine  Shot Wednesday
# finished page Makes me sad
# finished page Saturday Moring Roll Call
# finished page Sunday Morning Roll Call
# finished page Thursday Morning Roll Call
# finished page Why a C&P Exam for D2 when the VA has all the records and is supplying medication?
# finished page Friday morning Roll Call
# finished page well i filed
# finished page Blood in urine after pelvic salvage radiation
# finished page Marine passed from lung cancer.
# finished page Caregivers Program for the older Veterans
# finished page VA Healthcare and Medicare options
# finished page Will the VA cover a dental Implant now that im rated at 100%
# done page 2
# next url is https://vetsbenefits.net/will-the-va-cover-a-dental-implant-now-that-im-rat-t120465-s80.html
# finished page Thursday Morning Roll Call
# finished page GW related vs combat related
# finished page DPAA identifies remains of Army chaplain, Medal of Honor recipient who died a prisoner of war
# finished page Trying to help my Dad
# finished page Luke AFB
# finished page VES C&P for heart exam completed today
# finished page Tapatalk Network Digest
# finished page Hypertension claim question
# finished page Transitions lenses feedback
# finished page Proving Vietnam Service Medal and VA Healthcare Eligibility
# finished page New here-helping my Dad
# finished page Uncertainty of claim
# finished page SSDI Question about filing timeline requirements
# finished page More Tractor Stuff
# finished page DEFORMITY OF THE PENIS 0% SC
# finished page Hypothyroid
# finished page Denial of VA claim
# finished page New claim filed. Why are all other disabilities listed as New Claims also ?
# finished page Back pay for 100% awarded disability is wrong
# finished page Hypertension Presumptive- History
# finished page 70% still trying to work
# finished page Wednesday Morning Roll Call
# finished page Is neck and back rating separate ?
# finished page Whats most common medication that VA gives for anxiety and which one might cause headache and migraine ?
# finished page Thank you!
# finished page Thoracolumbar Spine L5- S-1 herniated Disc & Arthritis
# finished page Painful Scars from Eczema
# finished page IVDS and sciatica of both legs increase exam
# finished page 100% PTSD total since 2010, just notified of C & P
# finished page VA Examiner Added Disability
# finished page TDIU @ 70%
# finished page Service treatment records
# finished page H.R. 6933
# finished page Ssdi reconsideration
# finished page Champva Meds By Mail
# finished page Tuesday Morning Roll Call
# finished page Accepted?
# finished page Marginal Work
# finished page IU and PUA
# finished page PTSD vs Major Depression
# finished page Shocked!
# finished page Does an appeal to the Board of Veterans' Appeals show up on EBenefits?
# finished page ROM c&p
# finished page VA Cue or Reconsideration?  VA Code 8100
# finished page C&P Exams
# finished page Covid Vaccine
# finished page Female service women pay far more  for uniforms than male members
# finished page C&P for Plantar Fascititis increase
# finished page Husband had cancer twice
# finished page Ruled Not Service Connected
# finished page Appeal cancelled why
# finished page Court awards $2.3 billion to USS Pueblo crew, more than 50 years after they were held in North Korea
# finished page Record review for C @ P exam.
# finished page DFAS retirement backpay for discharge upgrade timeline?
# finished page New Hearing Aids
# finished page Monday Morning Roll Call
# finished page Range of motion question
# finished page Question on IHD claim
# finished page VA Claim  Number
# finished page Hypothryoidism and Agent Orange
# finished page Does a change in the speech discrimination test effect the disability calculation?
# finished page Need New MH Providers After Move?
# finished page Sunday Morning Roll Call
# finished page HLR Closed
# finished page Housing
# finished page No question is stupid, but often you will find it was asked before. Check the archives.
# finished page Loss of use
# finished page The new check out line
# finished page file now or wait for NRPC to reopen to get records for my non-VA doctor to review and write nexus?
# finished page Adjustable bed from the VA
# finished page Best/Worse Viet Nam War Movie.
# finished page Vietnam Vet Health Worsening
# finished page Adopted girl learns she is a Princess
# finished page Post Presumptive awards here
# done page 2
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s80.html
# done page 3
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s120.html
# done page 4
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s160.html
# done page 5
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s200.html
# done page 6
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s240.html
# done page 7
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s280.html
# done page 8
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s320.html
# done page 9
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s360.html
# done page 10
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s400.html
# done page 11
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s440.html
# done page 12
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s480.html
# done page 13
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s520.html
# done page 14
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s560.html
# done page 15
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s600.html
# done page 16
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s640.html
# done page 17
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s680.html
# done page 18
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s720.html
# done page 19
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s760.html
# done page 20
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s800.html
# done page 21
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s840.html
# done page 22
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s880.html
# done page 23
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s920.html
# done page 24
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s960.html
# done page 25
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s1000.html
# done page 26
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s1040.html
# done page 27
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s1080.html
# done page 28
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s1120.html
# done page 29
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s1160.html
# done page 30
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s1200.html
# done page 31
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s1240.html
# done page 32
# next url is https://vetsbenefits.net/post-presumptive-awards-here-t54138-s1280.html
# finished page Any older seriously disabled veteran been accepted into Level One of the stipended Caregiver's program?
# finished page Outside doc reports / visits
# finished page Indica Gummies for Sleep
# finished page Minor Ailments, should I file?
# finished page Air National Guard help
# finished page weather
# done page 2
# next url is https://vetsbenefits.net/weather-t193509-s80.html
# finished page Ischemic Heart Disease and Agent Orange
# finished page Saturday Morning Roll Call
# finished page Sleep Apnea at the BVA as of March 2020 via Direct Review no additional evidence..ETIC?
# finished page 70% IU TandP
# finished page Won P and T but still have higher level review pending
# finished page When to add nexus letter
# finished page This will boost your spirits
# finished page Do Raters lurk here?
# finished page Vitamine D deficiency question.
# finished page Friday Morning Roll Call
# finished page Maybe it's just me.
# finished page Wednesday Morning Roll Call
# finished page The Board made a decision on your appeal
# finished page Too late to Appeal Mentally Incompetent?
# finished page Dependents' Educational Assistance
# finished page submitted appeal
# finished page 100% T&P Grants & Scholarships
# finished page Supplemental Claims
# finished page 82 year old Army Vet beats home intruder to death with shotgun
# finished page 100%pt and community care dental
# finished page Former Veterans Affairs hospice nurse sentenced to prison for stealing morphine meant for dying veteran
# finished page Heart Attack compensation question
# finished page Thursday Morning Roll Call
# finished page Sleep Apnea Post Active Duty
# finished page C &P exam
# finished page Marines, rejoice: Someone made crayons that are actually meant to be eaten
# finished page Good Ole Days,............?? LOL
# finished page Overrated Problem
# finished page TDIU Effective Date
# finished page COVID Screen - can they use it against you?
# finished page New Mail trucks
# finished page State veterans’ homes are required to report coronavirus data, but not all comply
# finished page Space Force announces new rank names
# finished page Covid predictions
# finished page Quesstions Re Filing Diabetes Clailm
# finished page Saturday Morning Roll Call
# finished page "Rating Control" opened on recently closed, awarded GW claim
# finished page Granted 100% P&T!!
# finished page Montana man again sentenced to 80 years for stabbing death over which military branch was better
# finished page The right way
# finished page 38 CFR 4.71a   Schedule of ratings—musculoskeletal system — Revision effective 2/7/21
# finished page Respect
# finished page thoracic radiculopathy
# finished page Is College Really Necessary?
# finished page Life insurance
# finished page CRSC for Disability, 9/11 Pentagon--Retiree Braman
# finished page COPD/Asthma
# finished page A Sensitive Husband (Humor)
# finished page Deja Vu All Over Again
# finished page Tuesday Morning Roll Call
# finished page Vocational Rehabilitation review
# finished page PTSD/TBI - Child Protective Service involvement (Is this the right forum?)
# finished page Letter in MAIL ABOUT REEVALUATION AFTER 20 YEARS
# finished page Finance history
# finished page Nexus for NSAID use and kidney CKD
# finished page MDD or Mental Disorder, Is there a difference
# finished page Tuesday Morning Roll Call
# finished page Monday Morning Roll Call
# finished page I wish I could report a civilian/non-veteran to Wounded Warriors
# finished page Mental Health during the Pandemic
# finished page Tommy the Soldier
# finished page Could somebody please take a look at this
# finished page granted appeal
# finished page Depleted uranium from tanks, ammo not tied to Gulf War syndrome, new study finds
# finished page CRSC Estimate--LadyHulk702
# finished page Burial at Sea..
# finished page Ulcerative Colitis
# finished page Docket numbers and Assignments to each judge.
# finished page 1040-x
# finished page Sunday Morning Roll Call
# finished page TriCare young adult program
# finished page Has anyone had a positive timeline with 1-2 months with BVA Appeal? It's been 5yrs
# finished page Applied CHAMPVA in Nov 2020 but P&T since 2015
# finished page These photos of a paratrooper caught in high voltage power lines are my worst f’ing nightmare
# finished page Snow Stories from Texas
# finished page C&p exam  and 100 p&t
# finished page VACHAMPS and open enrollment
# finished page VA.gov
# finished page SATURDAY MORNING ROLL CALL
# finished page DBQ Availability
# finished page DBQ / Prostate cancer
# finished page Adaptive Equipment in heavy snow area
# finished page PTSD diagnosis? I have another appointment next week.
# finished page Here we go again.  Money needed for other things so cut disabled veterans.  Read it and Weep
# finished page Brain burn
# finished page Friday morning Roll Call
# finished page Static Disability
# finished page CHAMPVA
# finished page QTC exam
# finished page CPAP Equipment Orders
# finished page Confusion abounds
# finished page Wake up call for disabled and wounded vets!
# finished page Thank You
# finished page P&T awarded
# finished page Delete
# finished page GWI - Supplement Claim Question
# finished page My kind of powdered donut
# finished page Thursday Morning Roll Call
# finished page Correct time
# finished page VA Contractor C&P Exams- will the VHA provide a copy?
# finished page Little hooters
# finished page Esoghageal cancer
# finished page Need help with SMC
# finished page Direct Review Appeal
# finished page Valentine's Day in Strange Times.
# finished page Leaving CONUS For The Philippines?  ( prospective Travelers)
# finished page Larry "Slash" Wagner
# finished page Wednesday Morning Roll Call
# finished page Monday Morning Roll Call
# finished page Thoughts on how to proceed or just move on?
# finished page Manlincon Remand
# finished page Eye Exams
# finished page Subsistence Allowance
# finished page 100% P&T and CHAMP VA
# finished page TDIU P&T Question
# finished page New With Question
# finished page So I been doing my homework for my smc remand
# finished page Senior Citizen Texting Codes:
# finished page retro payment with continued rfe?
# finished page HOT PEB Question TDRL / VA disability
# finished page 100% disability question, not P&T
# finished page recent 100% P&T award question
# finished page Left Knee Rating Clarification Needed
# finished page Va care and medicare
# finished page Female Marine recruits have arrived at Recruit Depot San Diego for training for the first time ever
# finished page Age 55 and the VA
# finished page Long wait for C&P
# finished page Double standard for corpsman
# finished page New C&P
# finished page withdrawal condition
# finished page VES ??
# finished page Sleep disturbance
# finished page Documented Pre-Diabetes - Denied HLR for DM2
# finished page SSDI saying I'm longer disabled
# finished page Haven't received a letter from bva about my remand
# finished page P&T possibility
# finished page Same last name question
# finished page Sunday Morning Roll Call
# finished page New Beagle pup
# finished page Lake Worth, a dead body, and the JP/Coroner
# finished page Colt ends 175 years as an American gunmaker with purchase by Czech company
# finished page SMC L - O?
# finished page VA Math/Combined Ratings
# finished page 100%P/T and Medicare
# finished page Frustrated Combat Veteran
# finished page Awarded new claim / But Confused?
# finished page Bilateral Factor
# finished page Saturday Morning Roll Call
# finished page I have discovered the perfect way to deal with being a bit overweight
# finished page PTSD 10 Years
# finished page DEERS / ID Card question
# finished page Valentine’s Day
# finished page VSO Near Atco, NJ
# finished page COMBINED VA RATING OF 100%
# finished page Loss of Use - Foot and Ankle
# finished page Effect of A-Fib on IHD
# finished page Records Request From Military Hospital?
# finished page Snowman revival
# finished page My Naval Reserve story
# finished page Friday Morning Roll Call
# finished page VA Pharmacy
# finished page reimbursement for service related treatment abroad
# finished page advice on MDD DBQ for UI claim
# finished page OSGLI Premium Decrease
# finished page Ebenefit letter
# finished page Rocky Mountain VA Medical Center
# finished page Exam
# finished page VA Just Recently asked for  Direct Deposit Info
# finished page Covid Injections
# finished page Compensation Service Case Review?
# finished page The Aftermath of Vietnam
# finished page VA Rating Reduction Thoughts - Beyond Frustrated
# finished page ejection fraction measures
# finished page AWARDED 100% P&T...Question effective date!
# finished page THURSDAY MORNING ROLL CALL
# finished page Newbie - Father is Vietnam Vet, VA patient, home repair services if any
# finished page VA Secretary #11
# finished page I would be grateful for any help
# finished page Cue challenge on 1997 rating  decision
# finished page How to keep rating if qualified?
# finished page Tuesday Morning Roll Call
# finished page Wednesday Moring Roll Call
# finished page Claims letter from DAV
# finished page Mental Health and Child Cusody
# finished page "The "OLD" Days
# finished page Heating and Air Question
# finished page Audit, back fill, and CUE
# finished page Confused about final PEB vs VA ratings
# finished page Paying it Forward...
# finished page IgA Nephropathy Nexus Letter
# finished page Workman’s Comp
# finished page Child Custody Case asking for AWARD LETTER ?
# finished page Champ VA question
# finished page Monday Morning Roll Call
# finished page Withdraw appeal
# finished page Incremental Payments?
# finished page dental care approval for outside procedures
# finished page Sunday Morning Roll Call
# finished page Ebennies (add disability)
# finished page Claims question
# finished page C&P for Radiculopathy of sciatic and femoral nerve
# finished page BVA hearing Feb 22 2020, Still waiting on the judge. Just received survey email.
# finished page PTSD and Guantanamo Bay, Cuba (maybe, maybe not) HELP
# finished page Cue challenge on 1997 rating  decision
# finished page How to keep rating if qualified?
# finished page Tuesday Morning Roll Call
# finished page Wednesday Moring Roll Call
# finished page Claims letter from DAV
# finished page Mental Health and Child Cusody
# finished page "The "OLD" Days
# finished page Heating and Air Question
# finished page Audit, back fill, and CUE
# finished page Confused about final PEB vs VA ratings
# finished page Paying it Forward...
# finished page IgA Nephropathy Nexus Letter
# finished page Workman’s Comp
# finished page Child Custody Case asking for AWARD LETTER ?
# finished page Champ VA question
# finished page Monday Morning Roll Call
# finished page Withdraw appeal
# finished page Incremental Payments?
# finished page dental care approval for outside procedures
# finished page Sunday Morning Roll Call
# finished page Ebennies (add disability)
# finished page Claims question
# finished page C&P for Radiculopathy of sciatic and femoral nerve
# finished page BVA hearing Feb 22 2020, Still waiting on the judge. Just received survey email.
# finished page PTSD and Guantanamo Bay, Cuba (maybe, maybe not) HELP

# %% [markdown]
# #### Zip and check outputs

# %%
# Zip all files
post_all_zip2 = zip(post_id_container, post_text, post_time,post_author,original_post_id_container, topic_titles_posts)#,
                  #original_post, original_post_time, original_post_poster_name) 
zipped_post2 = list(post_all_zip2) #Convert zip to list.
df_zipped_post3 = pd.DataFrame(zipped_post2, columns=['post_id_container','post_text','post_time','post_author',
                                                  'original_post_id_container', 'topic_title'])

# %%
df_zipped_post3.shape
# Out:
# (13378, 6)

# %%
df_zipped_post3.head(50)
# Out:
#       post_id_container  \
# 0   post_content1512116
# 1   post_content1512119
# 2   post_content1512095
# 3   post_content1512096
# 4   post_content1512097
# 5   post_content1512098
# 6   post_content1512103
# 7   post_content1512107
# 8   post_content1512111
# 9   post_content1512112
# 10  post_content1512113
# 11  post_content1512115
# 12  post_content1512117
# 13  post_content1512118
# 14  post_content1493453
# 15  post_content1493466
# 16  post_content1493468
# 17  post_content1493470
# 18  post_content1493471
# 19  post_content1493630
# 20  post_content1493666
# 21  post_content1493667
# 22  post_content1497880
# 23  post_content1497918
# 24  post_content1497919
# 25  post_content1498409
# 26  post_content1512114
# 27  post_content1511407
# 28  post_content1511414
# 29  post_content1511447
# 30  post_content1511853
# 31  post_content1511924
# 32  post_content1511936
# 33  post_content1512029
# 34  post_content1512068
# 35  post_content1512073
# 36  post_content1512089
# 37  post_content1512104
# 38  post_content1512106
# 39  post_content1512108
# 40  post_content1512110
# 41  post_content1510578
# 42  post_content1510595
# 43  post_content1510647
# 44  post_content1510650
# 45  post_content1510688
# 46  post_content1510692
# 47  post_content1510697
# 48  post_content1510711
# 49  post_content1510861
#
#                                                                                                                                                                                                                                                                                                                                                                                                           post_text  \
# 0                                                                                                                                                                                                                                                      Hi I sent in my wife’s claims and EOB Jan 2nd still nothing from ChampVA  how long does it take to get reimbursed  I tried calling but it’s a 30 minute wait
# 1                                                                                                                                                                                                                                Took about 3 months after applying and then sending in claims to be reimbursed.\n\nMonday morning is the worst time to call them.  Yes, there is a wait time for anytime you call.
# 2                                                                                                                                                                                                                                                                                                                                                                                Yo\n\nHere and present for Monday.
# 3                                                                                                                                                                                                                                                                                                                                                                  happy monday morning every one\n\n\n\n\n\n\n\n\n
# 4                                                                                                                                                                                                                                                                        Good Morning All. \n\n\t\t\t\n\t\t                    \n                \n                            \n        \t    \n\t\t\n\t\t\n\t\t\t
# 5                                                                                                                                                                                                                                                                                                                                                                                                     Morning folks
# 6                                                                                                                                                                                                                                        Morning all Happy Monday......since we're all getting vaccinated and toilet paper is limited....I might have room for one more\n\nSent from my SM-G970U using Tapatalk\n\n
# 7                               Hello from cool but sunny NC...Hope you'll have a good one.\n\n\n\nHello Springtime. Great to see these little critters back again.\n\n\n\t\t\t\n\t\t                    \n                \n                            \n        \t    \n\t\t\n\t\t\n\t\t\t\n\t\t\t\n\t\t                    \n                \n                            \n        \t    \n\t\t\n\t\t\n\t\t\t
# 8                                                                                                                                                                                                                                                                                                                                                       \n\nMorning everyone \n\n\nSent from my iPad using Tapatalk
# 9                                                                                                                                                                                                                                                                                                                                                                                                               yo.
# 10                                                                                                                                                                                                                                                                                                                                                         Good morning all.\nHere's another project for you Chief:
# 11                                                                                                                                                                                                                                                                                                                                                                                                               GM
# 12                                                                                                                                                                                                                                                                                                                                               Good Morning Everyone \n\nSent from my SM-N986U using Tapatalk\n\n
# 13                                                                                                                                                                                                                                                                                                                                                                                       Good Morning Everyone!\n\n
# 14  Hi I am currently rated at 50% for PTSD for the past 10 years or so. It has been getting worse over the years and now it has become significantly worse. I finally went for a increase which I avoided because I pretty much avoid most things. Anyway I just found that they denied my increase. This is what I expected and part of the reason I avoided asking for the increase to begin with. I went int...
# 15                                                                                                                                                                                                                                                                                                                               Should you dispute it ? Hard to say.  If the evidence is there, i suppose i would.
# 16                                                                                                    I am waiting to get a copy of the C&P report to see what the examiner wrote. But he told me what he was writing would be indicating the fact that I got worse. Isn't the opinion of the C&P examiner what matters? I have been service connected for close to 10 years and all of that is already documented.
# 17  sundowner41 wrote:I am waiting to get a copy of the C&P report to see what the examiner wrote. But he told me what he was writing would be indicating the fact that I got worse. Isn't the opinion of the C&P examiner what matters? I have been service connected for close to 10 years and all of that is already documented.\nHave you been engaged in treatment?\n\nIf so, what do your treatment record...
# 18                                                                                                                                                                                                                                                                While your symptoms made be worse, they may not rise to the level of any higher evaluation. \n\nHave you received the rating decision letter yet?
# 19                                                                                                                              Without treatment, PTSD WILL get worse as time goes by.\n\nIf you have not been getting treatment, then you have been hurting yourself.  You REALLY need to be getting ongoing treatment.\n\nNOTHING beats ongoing treatment records to show that your symptoms are getting worse.
# 20  The C&P examination is done in accordance to a disability benefits questionnaire.  There is a check list of symptoms that the examiner goes through.  \n\nWhen the rater gets the DBQ back they input the symptoms listed and their computer program suggests a rating.  The rater can agree with that rating, or bump it up/down one rating level based on the totality of evidence.  Any rater that lowers...
# 21  Keep in mind that your symptoms could all fall in the 50% range, and be worse than they were years ago.  \n\nHere is the CFR for 50% and above:\n\nGeneral Rating Formula for Mental Disorders: \n\nTotal occupational and social impairment, due to such symptoms as: \n\t\t\tgross impairment in thought processes or communication; \n\t\t\tpersistent delusions or hallucinations; grossly inappropriate...
# 22  Guldolphin wrote: ↑Nov 14, 2020The C&P examination is done in accordance to a disability benefits questionnaire.  There is a check list of symptoms that the examiner goes through.  \n\n\nI had my C&P exam yesterday.  She clearly didn't run down a check list of symptoms.  I had used a private doctor, recommended by a VA claim group, and that guy sounded much like he was using a list.   Is there...
# 23  Overlook7 wrote: ↑Dec 11, 2020Guldolphin wrote: ↑Nov 14, 2020The C&P examination is done in accordance to a disability benefits questionnaire.  There is a check list of symptoms that the examiner goes through.  \n\n\nI had my C&P exam yesterday.  She clearly didn't run down a check list of symptoms.  I had used a private doctor, recommended by a VA claim group, and that guy sounded much like h...
# 24  I've attached it here. \n\nFWIW, I've had numerous PTSD C&P's.  The one's where the Dr. didn't ask the questions on the DBQ, checked most of them no.   The one's that did go down the list verbatim, checked them off correctly in accordance with my answer (which we're yes).  The one's that didn't go by the DBQ we're mostly interested in my childhood upbringing, education, drugs and alcohol use o...
# 25                                                                                                                 #7 question #22 do you have that?\n\nIf you had that and it was currently documented in your treatment notes, if you were in some kind of treatment for your PTSD, that #22 is very critical for what VA is looking for when it comes to the 70% level. \n\n\nSent from my iPhone using Tapatalk
# 26  Hi Sorry for the long time without a reply. I lost another job and didnt have a computer for a while so I apologize. I actually am scheduled for a higher level review in 30min from now. I did get a copy of the C&P and the examiner did write in his opinions my PTSD has gotten worse but the boxes he checked indicate the 50% rating which I hope to clarify today. As far as treatment yes I am being...
# 27                          As known about 35 year ago I claimed SC for hypothyroidism caused by agent orange and of course it was denied. Fast forward to now, just had a c&p for it and the lady said yes its confirmed. The question I have now is will I be rated under the rules was back then or the new rules that were changed I believe in 2020 concerning the amount of compensation? Its a Nehmer claim.
# 28                                                                                                                                              It will initially be rated under the regulations in effect as of the effective date of service connection, whatever that turns out to be.  Any subsequent increase in the rating will be under the regulations in effect as of the date of the increase.\n\nCruiser
# 29                                                                                                            AGAIN CRUISER is right.. Under NEHMER, for IHD, they went back to grant date for Service Connection and the eligibility and rate for back then. Years ago a heart attack gave a person 1 year at 100%. Under Nehmer they granted the 1 year, of course the pay rate at 100% was a lot less then also.
# 30                                                                                                                                                                                                                                                                   The buying power of the 100% rate then was much higher than it is now.\nOur COLAs are computed using the "let them eat cat food"  CPI-W index.
# 31  I really wish the CPI-W index was always used.  VA Disability Rates were subject to Congressional approval just like Federal Pay rates were subject to Congressional approval until I think 1970.  However this  is not an absolute.  To get the automatic pay rate changesunder the CPI Congress has to approve the pay rates in the budgets for each Department.  I guess the best way to put it is unless...
# 32  The CPI-W  is based on a sample of  households where more than one-half of the household income comes from wage occupations, and at least one of the household's earners has been employed for at least 37 weeks during the previous 12 months. That is  a bit less than 30 percent of the U.S. population. \n CPI-U covers a larger population - it is based on sample of urban households designed to repr...
# 33                                                                                                                                                                                                                   If my original claim from 1982 is validated under Nehmers  for hypothyroidism, would the  “continuous medication required “ be grandfathered in and continued beyond 2014 when it was dropped?
# 34  tbfirm wrote: ↑10:14 AM - 1 day agoIf my original claim from 1982 is validated under Nehmers  for hypothyroidism, would the  “continuous medication required “ be grandfathered in and continued beyond 2014 when it was dropped?\nUnless something has changed since I retired Nehmer only applies to claims that were either denied or were still pending on or after September 25, 1985.  If this is stil...
# 35                                                                                                                                                                                                     Cruiser\nFiled in 82 and denied. Filed again in 2001 denied. Filed again in 2010 denied. Filed in 2018 Service Connected at 0%.  How should I proceed?I’ve been on continuous medication since first filing.
# 36                                                                                                                                                                                                                                                                                                                                                                  JMHO, get a VSO to help you proceed, good luck!
# 37  The first thing that jumps out at me is the fact that you were assigned a 0 percent evaluation.   Presumptive service connection is not warranted unless the condition is 10 percent.  \n\nAs for the effective date, I’m not aware of what the current instructions are.  Since you submitted a claim that was denied after September 25, 1985, I would suspect that date of claim to apply; however, like ...
# 38                                                                                                               Cruiser,  Since he was rated at 0% in 2018, and since it needs to be 10% or more to qualify for a presumptive award, would not the date that he could be evaluated at 10% be the controlling date?  Since a 0% was effective 2018, would not the effective date have to be later than the 0% date?
# 39                                                                                                                                                                                                                                                                                          The 0% may be based on the schedule change that took place in 2017.  Maybe it was not connected on a presumptive basis.
# 40  BROVET wrote: ↑9:02 AM - TodayCruiser,  Since he was rated at 0% in 2018, and since it needs to be 10% or more to qualify for a presumptive award, would not the date that he could be evaluated at 10% be the controlling date?  Since a 0% was effective 2018, would not the effective date have to be later than the 0% date?\nYes, unless they saw evidence that it was previously 10 percent but then i...
# 41  Since November 2020 I have 8-10 VA Travel claims still not paid.\n\nWas forced to go to the new online claim system for all but a couple of locations. All of those claims are now showing a Pending Manual Review Status.\n\nAlso have a couple of claims outstanding that were made at a Kiosk.\n\nI have receive no travel pay for any of these.\n\nI am 100 P&T.\n\nDoes anyone know of any problems wit...
# 42                                                                                                                                                                                                                        Same, Same...several travel appointments and no pay. I haven't visited the new online portal, however if you find out anything please share. \n\nSent from my SM-G970U using Tapatalk\n\n
# 43                                                                                                                                                                                                                                                                                                                               Having the same problems here. One pending from the Kiosk and one from the portal.
# 44                                                                                                                 Had one due from the 5th of November and another from the 12th of December, both submitted on paper.  They finally showed up a couple of days apart the last week in January.\n\nHave always submitted paper vouchers and always showed up like clockwork three weeks later.  Up to now that is.
# 45                                                                                                                                                                                                                                                        Dang I must be one of the few who havent had any issue's with my travel pay. I use the online tool. Dumb question, have you visited your travel office???
# 46                                                                                                                                                                                                                                                                                            Is filing on the kiosk not available anymore. That was the most convenient way to file even tho it was slower to pay.
# 47                                                                                                                                                                             My most recent trip was paid in about 5 days. I got the travel authorization paperwork done at the Derm clinic at the Tampa location. I haven't used the online one, I have had a lot of video connect appointments this past year!!
# 48                                                                                                                                I was having that problem, I called VA travel to ask the question. It would seem so were in the old system and had to be pushed through. With the others moved to the new system. Took me about 3 to 4 months to get everything fixed\n\nSent from my SM-G975U using Tapatalk\n\n
# 49  I stopped worrying about it about 6 mos ago.  I file my travel, I don’t get paid.  I grip. I moan.  I grown.  I call Travel.  I get pissed off.  I go to my next appointment.  I file my travel.  I don’t  get paid.  I gripe.  I ............  So I decided it wasn’t worth the effort to let it bother me.  I ZENNED it out of my existence.  \n\nSomeday the Universe is going to reverse itself and all ...
#
#                   post_time                        post_author  \
# 0    9:55 AM - Mar 22, 2021          ["POST_AUTHOR", "jrp419"]
# 1   10:05 AM - Mar 22, 2021          ["POST_AUTHOR", "EKco22"]
# 2    6:10 AM - Mar 22, 2021         ["POST_AUTHOR", "Chiefw3"]
# 3    6:30 AM - Mar 22, 2021            ["POST_AUTHOR", "Vetn"]
# 4    7:23 AM - Mar 22, 2021         ["POST_AUTHOR", "jim1392"]
# 5    7:41 AM - Mar 22, 2021          ["POST_AUTHOR", "Bigdmn"]
# 6    8:17 AM - Mar 22, 2021  ["POST_AUTHOR", "Truckmaster801"]
# 7    9:05 AM - Mar 22, 2021    ["POST_AUTHOR", "SkidRider 70"]
# 8    9:22 AM - Mar 22, 2021         ["POST_AUTHOR", "Mikesax"]
# 9    9:25 AM - Mar 22, 2021       ["POST_AUTHOR", "BigDrocks"]
# 10   9:25 AM - Mar 22, 2021             ["POST_AUTHOR", "Hal"]
# 11   9:47 AM - Mar 22, 2021       ["POST_AUTHOR", "Jerseybro"]
# 12   9:56 AM - Mar 22, 2021        ["POST_AUTHOR", "armymom4"]
# 13  10:01 AM - Mar 22, 2021     ["POST_AUTHOR", "ChandlerBob"]
# 14   9:30 AM - Nov 13, 2020     ["POST_AUTHOR", "sundowner41"]
# 15  10:07 AM - Nov 13, 2020        ["POST_AUTHOR", "USMC1987"]
# 16  10:15 AM - Nov 13, 2020     ["POST_AUTHOR", "sundowner41"]
# 17  10:32 AM - Nov 13, 2020          ["POST_AUTHOR", "Poston"]
# 18  10:45 AM - Nov 13, 2020          ["POST_AUTHOR", "EKco22"]
# 19   9:39 AM - Nov 14, 2020   ["POST_AUTHOR", "The Old Medic"]
# 20  12:48 PM - Nov 14, 2020      ["POST_AUTHOR", "Guldolphin"]
# 21  12:50 PM - Nov 14, 2020      ["POST_AUTHOR", "Guldolphin"]
# 22   2:32 PM - Dec 11, 2020       ["POST_AUTHOR", "Overlook7"]
# 23   5:07 PM - Dec 11, 2020      ["POST_AUTHOR", "Guldolphin"]
# 24   5:09 PM - Dec 11, 2020   ["POST_AUTHOR", "Johnny Rotten"]
# 25  10:58 PM - Dec 14, 2020        ["POST_AUTHOR", "Sprinter"]
# 26   9:41 AM - Mar 22, 2021     ["POST_AUTHOR", "sundowner41"]
# 27   2:08 PM - Mar 15, 2021    ["POST_AUTHOR", "livelsberger"]
# 28   2:40 PM - Mar 15, 2021         ["POST_AUTHOR", "Cruiser"]
# 29   8:13 PM - Mar 15, 2021           ["POST_AUTHOR", "Daman"]
# 30  12:28 PM - Mar 19, 2021           ["POST_AUTHOR", "57AHC"]
# 31  10:31 AM - Mar 20, 2021       ["POST_AUTHOR", "wasGIonce"]
# 32  11:19 AM - Mar 20, 2021            ["POST_AUTHOR", "Nick"]
# 33  10:14 AM - Mar 21, 2021          ["POST_AUTHOR", "tbfirm"]
# 34   5:05 PM - Mar 21, 2021         ["POST_AUTHOR", "Cruiser"]
# 35   6:36 PM - Mar 21, 2021          ["POST_AUTHOR", "tbfirm"]
# 36   9:43 PM - Mar 21, 2021            ["POST_AUTHOR", "LeoP"]
# 37   8:45 AM - Mar 22, 2021         ["POST_AUTHOR", "Cruiser"]
# 38   9:02 AM - Mar 22, 2021          ["POST_AUTHOR", "BROVET"]
# 39   9:10 AM - Mar 22, 2021          ["POST_AUTHOR", "EKco22"]
# 40   9:12 AM - Mar 22, 2021         ["POST_AUTHOR", "Cruiser"]
# 41   9:15 AM - Mar 09, 2021   ["POST_AUTHOR", "dontcatchmany"]
# 42  11:15 AM - Mar 09, 2021  ["POST_AUTHOR", "Truckmaster801"]
# 43   4:05 PM - Mar 09, 2021       ["POST_AUTHOR", "Richard84"]
# 44   4:18 PM - Mar 09, 2021        ["POST_AUTHOR", "BigSweet"]
# 45   7:58 PM - Mar 09, 2021          ["POST_AUTHOR", "Bigdmn"]
# 46   8:16 PM - Mar 09, 2021       ["POST_AUTHOR", "Herdgrunt"]
# 47   9:46 PM - Mar 09, 2021            ["POST_AUTHOR", "LeoP"]
# 48  12:02 AM - Mar 10, 2021       ["POST_AUTHOR", "kelly1984"]
# 49   9:31 PM - Mar 10, 2021       ["POST_AUTHOR", "wasGIonce"]
#
#    original_post_id_container              topic_title
# 0         post_content1512116          ChampVA  Claims
# 1         post_content1512116          ChampVA  Claims
# 2         post_content1512095  Monday Moring Roll Call
# 3         post_content1512095  Monday Moring Roll Call
# 4         post_content1512095  Monday Moring Roll Call
# 5         post_content1512095  Monday Moring Roll Call
# 6         post_content1512095  Monday Moring Roll Call
# 7         post_content1512095  Monday Moring Roll Call
# 8         post_content1512095  Monday Moring Roll Call
# 9         post_content1512095  Monday Moring Roll Call
# 10        post_content1512095  Monday Moring Roll Call
# 11        post_content1512095  Monday Moring Roll Call
# 12        post_content1512095  Monday Moring Roll Call
# 13        post_content1512095  Monday Moring Roll Call
# 14        post_content1493453            PTSD Increase
# 15        post_content1493453            PTSD Increase
# 16        post_content1493453            PTSD Increase
# 17        post_content1493453            PTSD Increase
# 18        post_content1493453            PTSD Increase
# 19        post_content1493453            PTSD Increase
# 20        post_content1493453            PTSD Increase
# 21        post_content1493453            PTSD Increase
# 22        post_content1493453            PTSD Increase
# 23        post_content1493453            PTSD Increase
# 24        post_content1493453            PTSD Increase
# 25        post_content1493453            PTSD Increase
# 26        post_content1493453            PTSD Increase
# 27        post_content1511407       Old or new rating?
# 28        post_content1511407       Old or new rating?
# 29        post_content1511407       Old or new rating?
# 30        post_content1511407       Old or new rating?
# 31        post_content1511407       Old or new rating?
# 32        post_content1511407       Old or new rating?
# 33        post_content1511407       Old or new rating?
# 34        post_content1511407       Old or new rating?
# 35        post_content1511407       Old or new rating?
# 36        post_content1511407       Old or new rating?
# 37        post_content1511407       Old or new rating?
# 38        post_content1511407       Old or new rating?
# 39        post_content1511407       Old or new rating?
# 40        post_content1511407       Old or new rating?
# 41        post_content1510578                VA Travel
# 42        post_content1510578                VA Travel
# 43        post_content1510578                VA Travel
# 44        post_content1510578                VA Travel
# 45        post_content1510578                VA Travel
# 46        post_content1510578                VA Travel
# 47        post_content1510578                VA Travel
# 48        post_content1510578                VA Travel
# 49        post_content1510578                VA Travel

# %% [markdown]
# ### Create Subset
# ...enabling more targeted analysis

# %%
df_zipped_post4_2019_sept_up = df_zipped_post4[df_zipped_post4.month >= '2019-09']

# %%
pickle.dump(df_discussion_links_no_dict, open("df_discussion_links_no_dict_2020-03-14_11AM.p", "wb"))

df_discussion_links_no_dict_pickle = pickle.load(open("df_discussion_links_no_dict_2020-03-14_11AM.p", "rb"))

# %%
pickle.dump(df_zipped_post2, open("df_zipped_post2_2020-03-14_11AM.p", "wb"))

df_zipped_post2_pickle = pickle.load(open("df_zipped_post2_2020-03-14_11AM.p", "rb"))

# %%
df_zipped_post2_pickle.shape
# Out:
# (13177, 6)

# %%
pickle.dump(df_zipped_post3, open("df_zipped_post3_2020-03-22_11AM.p", "wb"))

df_zipped_post3_pickle = pickle.load(open("df_zipped_post3_2020-03-22_11AM.p", "rb"))

# %%
df_zipped_post3_pickle.shape
# Out:
# (13378, 6)
